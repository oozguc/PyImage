# %%
import sys
sys.path.insert(0, "/Users/aimachine/PyImage/utils")
import numpy as np
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from plot_utils import multiplotlineX, overlaymultiplotX
from bokeh.plotting import figure, output_file, show
from bokeh.io import export_png, output_notebook

# %%
sourcedir = '/Users/aimachine/Documents/JuliaData/ResultsTxtFiles/'
saveplotdir= '/Users/aimachine/Documents/JuliaData/ResultsTxtFiles/'

# %%
Path = os.path.join(sourcedir, '*.txt')
X = sorted(glob.glob(Path))
Names = sorted(glob.glob(Path))


for file in Names:
  


 base = os.path.split(file)[-1]

 Filename = os.path.splitext(base)
 
 time , TotalIntCell, AvIntCell, AreaCell, TotalIntCloud, AvIntCloud, AreaCloud = np.loadtxt(file, delimiter = ',', skiprows = 1, unpack=True)
 print('Displaying Plot for :', Filename[0])
       
 
 #Bokeh plots
 p = figure(title='Nuclei and Cloud Intensity', x_axis_label='Time', y_axis_label='Amplitude')
 p.line(time, TotalIntCell, legend = "Nuclei Intensity-time", line_width = 2)
 p.line(time, TotalIntCloud, legend = "Cloud Intensity-time", line_width = 2, line_color='red')
 output_notebook()
 show(p)
 export_png(p, filename=saveplotdir + 'TotalIntensity' + Filename[0] + '.png')
# Out:
# Displaying Plot for : CTrackSUM_C1-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID0Channel 1
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4dd15e7c-1b5b-4462-b5d6-04161ec8639b">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7c466de5-34a4-4e4a-9312-f362555d232a"></div>
# </div>
# Displaying Plot for : CTrackSUM_C1-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID1Channel 1
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="437b67e0-a430-4e01-9be1-ba76df08c130">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="550da8e5-0455-4291-b0eb-db6ae9fbc162"></div>
# </div>
# WARNING:bokeh.io.export:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# Displaying Plot for : CTrackSUM_C1-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID2Channel 1
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fb8bf0c1-a535-472f-8125-9951e75617b4">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="19ed452b-f007-495a-8da0-8a1a60a04b0e"></div>
# </div>
# WARNING:bokeh.io.export:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# Displaying Plot for : CTrackSUM_C2-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID0Channel 2
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="229dc3d5-fcda-49f6-99f7-f4f0c2bf18a5">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8836ee9f-afe1-4655-a9f9-01ead9b73ff9"></div>
# </div>
# WARNING:bokeh.io.export:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# Displaying Plot for : CTrackSUM_C2-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID1Channel 2
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="70e9a2c7-bb97-4465-a404-02d7e730f9d7">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c7aa67c5-3315-4a07-9a40-44deadeaad84"></div>
# </div>
# WARNING:bokeh.io.export:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# Displaying Plot for : CTrackSUM_C2-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID2Channel 2
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1cd56b73-1d9c-4350-8880-1eb8795dacbb">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4c21987b-a38f-4c08-a30e-d89a8c793e0d"></div>
# </div>
# WARNING:bokeh.io.export:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.

# %%
for file in Names:
  


 base = os.path.split(file)[-1]

 Filename = os.path.splitext(base)
 
 time , TotalIntCell, AvIntCell, AreaCell, TotalIntCloud, AvIntCloud, AreaCloud = np.loadtxt(file, delimiter = ',', skiprows = 1, unpack=True)
 print('Displaying Plot for :', Filename[0])
   
#Non-Bokeh boring plots      
 overlaymultiplotX(TotalIntCell, TotalIntCloud, time, "Nuclei Intensity(cloud excluded)","CloudIntensity",saveplotdir,Filename[0] )
# Out:
# Displaying Plot for : CTrackSUM_C1-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID0Channel 1
# Displaying Plot for : CTrackSUM_C1-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID1Channel 1
# Displaying Plot for : CTrackSUM_C1-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID2Channel 1
# Displaying Plot for : CTrackSUM_C2-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID0Channel 2
# Displaying Plot for : CTrackSUM_C2-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID1Channel 2
# Displaying Plot for : CTrackSUM_C2-20180629-TX1072-CL60-Dox0820_visit_1.tifTrackID2Channel 2
