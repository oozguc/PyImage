# %%
import sys
sys.path.insert(0, "/Users/aimachine/PyImage/utils")
import numpy as np
from scipy import signal
import scipy.fftpack as fftpack
from scipy.fftpack import fftfreq
import matplotlib.pyplot as plt
import os
from scipy.signal import blackman
from tifffile import imread
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.fftpack import fft
from matplotlib.colors import LogNorm
from Normalize import normalizeFloat, normalizeMinMax, Path, save_tiff_imagej_compatible

# %%
targetdir = '/Users/aimachine/Documents/JLMCurvature/FFTImageTest/'
sourceimage = '/Users/aimachine/Documents/JLMCurvature/FFTImageTest/FullResolution.tif'

base = os.path.split(sourceimage)[-1]

Filename = os.path.splitext(base)

# %%
#Enter time unit in seconds
Time_unit = 5
#Cut Section of image before the alst pixel
CutSectionAfter = 0
#Enter start y pixel unit for the section
StartSection = 0
#Enter end y pixel unit for section
EndSection = 50
#Range of Plot in Hertz
maxXrange = 0.1

# %%
y = imread(sourceimage)
Xrange = y.shape[0]
Yrange = y.shape[1]
cutY = y[:,CutSectionAfter:Yrange]
y = cutY
plt.figure()
plt.imshow(y, plt.cm.Spectral)
plt.title('Original image')

print(Xrange, " ", Yrange)
width = int(EndSection - StartSection)
block = int(Xrange / width)

Start = StartSection
End = EndSection
print(block)
axes = 'XY'
# Out:
# 745   122
# 14

# %%
for i in range(block):
 plt.figure()
 
 fsmally = y[StartSection:EndSection, :]
 
    
 plt.imshow(fsmally, plt.cm.Spectral)
 plt.title('Image Segment of interest' + ' = ' + str(i))

# %%
#We want the phase of the block
def doFilterFFT(image, block, filter):
   addedfft = 0 
   addedphase = 0
   Phase = image 
   PointsSample = image.shape[1] 
   for i in range(image.shape[0]):
      if filter == True:   
       w = blackman(PointsSample)
      if filter == False:
       w = 1
      strip = image[i,:]
      fftresult = fft(w * strip)
      phase = np.angle(fftresult)
      Phase[i,:] = phase  
      addedfft += np.abs(fftresult)
      addedphase += phase
   xf = fftfreq(PointsSample, Time_unit)
   
   
   return 2.0/PointsSample * addedfft[1:int(PointsSample//2)], xf[1:int(PointsSample//2)] , Phase

# %%
StartSection = Start
EndSection = End
allfrequ = 0


startblock = 0;
endblock = 1;
 
while endblock < block :
      plt.figure()
   
 
      fsmally = y[StartSection:EndSection, :]

      onedimg, frequ, phase = doFilterFFT(fsmally, startblock, False)
    
      StartSection = EndSection
      EndSection += width    
      fsmally = y[StartSection:EndSection, :]
    
    
      onedimgnext, frequnext, phasenext = doFilterFFT(fsmally, endblock, False)
      plt.figure()
      plt.imshow(phase, plt.cm.Spectral)
      plt.title('Image Segment of interest' + ' = ' + str(startblock))
      plt.figure()
        
      plt.imshow(phasenext, plt.cm.Spectral)
      plt.title('Image Segment of interest' + ' = ' + str(endblock))
      save_tiff_imagej_compatible((targetdir + 'PhaseSegment' + str(startblock) + Filename[0]) , phase, axes)
      save_tiff_imagej_compatible((targetdir + 'PhaseSegment' + str(endblock) + Filename[0]) , phasenext, axes)
      save_tiff_imagej_compatible((targetdir + 'PhaseDifferenceSegment'+ str(startblock) + str(endblock) + Filename[0]) , phase - phasenext, axes)  
      plt.figure()
      plt.imshow(phase - phasenext, plt.cm.Spectral)
      plt.title('Difference image' + ' = ' + str(startblock) + " " + str(endblock))  
      startblock = startblock + 1
      endblock = endblock + 1  
      
        
StartSection = Start
EndSection = End
# Out:
# /Users/aimachine/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
