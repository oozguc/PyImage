# %%
import sys
sys.path.insert(0, "/Users/aimachine/PyImage/utils")
import numpy as np
from scipy import signal
from scipy.fftpack import fftfreq

import os
from plot_utils import multiplot
from scipy.signal import blackman
from tifffile import imread
from mpl_toolkits.mplot3d import Axes3D

from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.fftpack import fft
from matplotlib.colors import LogNorm
from Normalize import normalizeFloat, normalizeMinMax, Path, save_tiff_imagej_compatible
from Strip2DFFT import doFilterFFT, do2DFFT, do2DInverseFFT, CrossCorrelation

# %%
targetdir = '/Users/aimachine/Documents/KymoGraphsForFFT/NewKymographs/'
sourceimageA = '/Users/aimachine/Documents/KymoGraphsForFFT/NewKymographs/KymographN5Circle.tif'
sourceimageB = '/Users/aimachine/Documents/KymoGraphsForFFT/NewKymographs/KymographN5Circle.tif'
base = os.path.split(sourceimageA)[-1]

Filename = os.path.splitext(base)

# %%
#Enter time unit in seconds
Time_unit = 5


#Enter start y pixel unit for the section
StartSection = 0
#Enter end y pixel unit for section
EndSection = 500
#Range of Plot in Hertz
maxXrange = 0.1

# %%
imageA = imread(sourceimageA)
Xrange = imageA .shape[0]
Yrange = imageA .shape[1]
print(Xrange, " ", Yrange)




width = int(EndSection - StartSection)
block = int(Xrange / width)
cutX = imageA

imageA  = cutX


Start = StartSection
End = EndSection

axes = 'XY'
# Out:
# 551   241

# %%
imageB = imread(sourceimageB)
Xrange = imageB .shape[0]
Yrange = imageB .shape[1]
print(Xrange, " ", Yrange)




width = int(EndSection - StartSection)
block = int(Xrange / width)
cutX = imageB

imageB  = cutX


Start = StartSection
End = EndSection

axes = 'XY'
# Out:
# 551   241

# %%
crosscorrelation = CrossCorrelation(imageA, imageB)

multiplot(imageA, imageB, crosscorrelation, "Original ImageA", "Original ImageB", "Cross Correlation")

# %%
save_tiff_imagej_compatible((targetdir + "CrossCorrelation" +os.path.basename(Filename[0])) , crosscorrelation, axes)
