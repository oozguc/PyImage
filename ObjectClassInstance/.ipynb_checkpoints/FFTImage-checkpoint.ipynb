# %%
import sys
sys.path.insert(0, "/Users/aimachine/PyImage/utils")
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from tifffile import imread
from scipy.fftpack import fft, fftshift
from Normalize import normalizeFloat, normalizeMinMax, Path, save_tiff_imagej_compatible

# %%
targetdir = '/Users/aimachine/Documents/JLMCurvature/'
y = imread('/Users/aimachine/Documents/JLMCurvature/FullResolution.tif')

# %%
plt.figure()
plt.imshow(y, plt.cm.Spectral)
plt.title('Original image')
Xrange = y.shape[0]
Yrange = y.shape[1]
print(Xrange, " ", Yrange)
# Out:
# 520   242

# %%
# Show the results

def plot_spectrum(ffty):
    from matplotlib.colors import LogNorm
    # A logarithmic colormap
    plt.imshow(ffty, norm=LogNorm(vmin=10))
    plt.colorbar()

# %%
FFTback = y;
for i in range(0, Xrange):
   oneD = y[i,:]
   ffty = fft(oneD)
   FFTback[i,:] = ffty
# Out:
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/site-packages/ipykernel/__main__.py:5: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
plt.imshow(FFTback, plt.cm.Spectral)

plt.figure()
plot_spectrum(FFTback)
plt.title('Fourier transform')
axes = 'XY'
save_tiff_imagej_compatible((targetdir + 'FFTResult.tif') , FFTback, axes)
