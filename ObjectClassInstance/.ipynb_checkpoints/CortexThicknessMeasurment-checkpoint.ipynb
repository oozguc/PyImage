# %%
import sys
sys.path.insert(0, "/Users/aimachine/PyImage/utils")
import numpy as np
from PIL import Image
import os
from tifffile import imread
import matplotlib.pyplot as plt
from Normalize import normalizeFloat, normalizeMinMax, Path, save_tiff_imagej_compatible
from plot_utils import singleplot, plotXY, doubleplot
from GaussFit import StripFit, Linescan
from HoughLine import show_hough_linetransform, show_ransac_points_line, show_plot
from bokeh.models import Label
from bokeh.plotting import figure, show, output_notebook
from IPython.display import clear_output
from bokeh.models import Range1d
import csv
from GaussFit import MakePath

# %%
targetdir = '/Users/aimachine/Documents/New_Folder/LineScanTest/500nmTest/'

Actinimage = '/Users/aimachine/Documents/New_Folder/LineScanTest/500nmTest/LineScanB.tif'

Membraneimage = '/Users/aimachine/Documents/New_Folder/LineScanTest/500nmTest/LineScanA.tif'


#Enter time unit in seconds
Time_unit = 1
#Enter pixel to micrometer conversion
Xcalibration = 0.069
#Enter the number of pixels to be included in the fit
Fitaround= 8

#Symmetric psf as input (micrometers)
psf = 0.17
showaftertime = 10
inisigmaguess =  psf
#Size of linescan
skip = 50
singleblock = 40 

#Number of segments
numsegments = 10
id = []
for i in range(0, numsegments):
    id.append(i)
    
MakePath(targetdir)    
save_dir = targetdir + 'ls_data'    
MakePath(save_dir)

# %%
Actin = imread(Actinimage)
Membrane = imread(Membraneimage)

doubleplot(Actin, Membrane, 'Actin Channel', 'Membrane Channel')
blockimageActin = []
blockimageMembrane = []

i = 0
while i < Actin.shape[0]:
       
   blockActin = Actin[i:i + singleblock,:]/np.amax(Actin[i:i + singleblock,:], 0)
   blockMembrane = Membrane[i:i + singleblock,:]/np.amax(Membrane[i:i + singleblock,:],0)
   
   blockimageActin.append(blockActin)
   blockimageMembrane.append(blockMembrane)
   doubleplot(blockActin, blockMembrane, 'Actin Channel', 'Membrane Channel')
   i = i + singleblock + skip 

halflength = int(len(blockimageActin)/2)
otherhalf = len(blockimageActin) - halflength
totallength = len(blockimageActin)

# %%
# %%time
#Fit all blocks

Thickness = []
Time = []
for i in range(0, totallength):
 print('block id', i+1)   
 Actin = blockimageActin[i]
 Membrane = blockimageMembrane[i]
 
 StripFit(Actin, Membrane, Time_unit, Xcalibration, Fitaround, psf, inisigmaguess, showaftertime, Thickness, Time)
 


 print("Thickness (min)",np.min(Thickness) *1000, "nm")
 print("Thickness (median)",np.median(Thickness) *1000, "nm")
 print("Thickness (max)",np.max(Thickness) *1000, "nm")
 Thickness_time = np.column_stack([Time, Thickness]) 

 show_ransac_points_line(Thickness_time, min_samples=2, residual_threshold=0.5, max_trials=1000, Xrange = Time[-1], displayoutlier = False)
    
    

 hist, edges = np.histogram((Thickness), density=False, bins='auto')
 p = figure(title="Estimated Cortex Thickness = " + str('%.5f'%np.abs(edges[np.argmax(hist)] * 1000)) + 'nm', y_axis_label='Counts',x_axis_label='Thickness(um)')
 listedges = edges.tolist()
 listhist = hist.tolist()
 output_notebook()
 p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
    fill_color="#036564", line_color="#033649")
 for  i in range(0,len(listhist)):
  if listhist[i] > 0:
   mytext = Label(x=listedges[i], y=listhist[i], text=str('%.4f'%listedges[i]))
   p.add_layout(mytext)
 show(p)

 #clear_output(wait = True)
# Out:
# block id 1
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/aimachine/PyImage/utils/GaussFit.py:343: RuntimeWarning: invalid value encountered in true_divide
#   m_left = (self.i[self.left_index_right] - self.i[self.left_index_left]) /  (self.x[self.left_index_right] - self.x[self.left_index_left])
# /Users/aimachine/PyImage/utils/GaussFit.py:359: RuntimeWarning: invalid value encountered in true_divide
#   m_right = (self.i[self.right_index_right] - self.i[self.right_index_left]) / (self.x[self.right_index_right] - self.x[self.right_index_left])
# /Users/aimachine/PyImage/utils/GaussFit.py:419: RuntimeWarning: invalid value encountered in log
#   (self.actin.i_in - i_c_start  ))))
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 9.86763104e+03  1.11632432e+01  1.30889316e+00 -3.51636552e+02]
# Actin Fit: [ 4.94688571e+03  9.36212659e+00  1.70668079e+00 -2.09798604e+02]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 741.5428584514908 1.679664588136929 1.0176156195389559
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 9.65696703e+03  1.08024317e+01  1.32466528e+00 -3.55636170e+02]
# Actin Fit: [381.18649088   3.92658712   1.69977133 -37.73069064]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 697.4899784797977 1.6734102739990067 1.0235202400668573
# Thickness (min) 691.9444159127659 nm
# Thickness (median) 713.8462605757398 nm
# Thickness (max) 770.960214372363 nm
# Ransac Slope =  -1.641e-04
# Regression Slope =  -1.641e-04
# Mean Thickness (After outlier removal) =  0.716 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="add1c52b-5d25-44b9-9c05-25084a986586">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="36b51c7e-73e1-4006-b0d1-1882168a9ec7"></div>
# block id 2
# Thickness (min) 691.9444159127659 nm
# Thickness (median) 710.2192621512453 nm
# Thickness (max) 770.960214372363 nm
# Ransac Slope =  -1.096e-04
# Regression Slope =  -1.096e-04
# Mean Thickness (After outlier removal) =  0.715 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4ccdf511-277a-4be4-890e-b27e7b9678c8">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3c38083d-0996-49fb-8224-5bec0583ffec"></div>
# block id 3
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 1.70338506e+03  6.69149837e+00  1.36594884e+00 -1.00550596e+02]
# Actin Fit: [ 4.46773002e+03  9.35113058e+00  1.79664064e+00 -1.89603234e+02]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 810.5871021164738 1.7712423878383643 1.0112265173345163
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 6.77276255e+03  1.05481330e+01  1.41090844e+00 -2.55150622e+02]
# Actin Fit: [ 2.42256642e+03  7.51022557e+00  1.85324752e+00 -1.27684433e+02]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 831.8837550547466 1.8268503145962292 1.010187542941199
# Thickness (min) 691.9444159127659 nm
# Thickness (median) 769.0008564757165 nm
# Thickness (max) 847.642233052434 nm
# Ransac Slope =  -4.831e-04
# Regression Slope =  -4.831e-04
# Mean Thickness (After outlier removal) =  0.761 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e796d12b-fd5d-4a40-81f0-a071d1667c29">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="14961b47-6702-4fcf-b962-72a068f5e529"></div>
# block id 4
# Thickness (min) 599.0934134170342 nm
# Thickness (median) 741.5428584514908 nm
# Thickness (max) 847.642233052434 nm
# Ransac Slope =  1.984e-04
# Regression Slope =  1.984e-04
# Mean Thickness (After outlier removal) =  0.752 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4666d494-72e1-4a23-be26-339810db6331">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="93f2af59-19dc-4f9f-b43d-6bbd36de404b"></div>
# block id 5
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 5.90223780e+03  9.19063974e+00  1.48668300e+00 -2.55195257e+02]
# Actin Fit: [100.58106565   2.48743781   1.85086556 -15.13106691]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 677.2003438283168 1.825283170609665 1.0304355960874128
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 5.54996458e+03  8.91455402e+00  1.39766969e+00 -2.47371582e+02]
# Actin Fit: [ 1.65465314  0.61000416  1.76899162 -0.08157847]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 690.0894161205927 1.7427144029281658 1.025965047739347
# Thickness (min) 599.0934134170342 nm
# Thickness (median) 736.898862387608 nm
# Thickness (max) 847.642233052434 nm
# Ransac Slope =  -3.983e-06
# Regression Slope =  -3.983e-06
# Mean Thickness (After outlier removal) =  0.742 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7dcdef4d-8046-42f6-98b7-5b0f1a8e3fea">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4193a9c2-2234-4b2d-b355-a5f24145e4c8"></div>
# block id 6
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 6.38222924e+03  9.83014972e+00  1.48126828e+00 -2.58012021e+02]
# Actin Fit: [0.92636107 0.51350991 1.89265479 0.28328168]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 768.8702109226025 1.8657033831433685 1.017171524191252
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [0.35124254 0.36815631 1.45907885 0.61953488]
# Actin Fit: [ 2.29680745e+03  7.04649259e+00  1.84948462e+00 -1.29037314e+02]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 730.5760531076404 1.8243668807946452 1.017932280468453
# Thickness (min) 599.0934134170342 nm
# Thickness (median) 735.7938140535971 nm
# Thickness (max) 847.642233052434 nm
# Ransac Slope =  5.210e-04
# Regression Slope =  5.210e-04
# Mean Thickness (After outlier removal) =  0.739 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b070e98c-67ec-48b3-90f3-48283d824e8a">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0b2cfe13-9450-417e-a488-15215995bc87"></div>
# block id 7
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 7.53133046  0.89299577  1.33991949 -2.36371667]
# Actin Fit: [0.45235327 0.37450101 1.68275356 0.51953751]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 637.8557311999557 1.6588473585427292 1.0388825355413074
# Thickness (min) 599.0934134170342 nm
# Thickness (median) 731.8992411157768 nm
# Thickness (max) 847.642233052434 nm
# Ransac Slope =  5.453e-04
# Regression Slope =  5.453e-04
# Mean Thickness (After outlier removal) =  0.734 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6638e61c-b97d-4dc9-9040-5a94e4831adc">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1146592b-fb98-4973-be53-8cf336a1aecd"></div>
# block id 8
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 1.06947942e+04  1.22187971e+01  1.51833355e+00 -3.48177352e+02]
# Actin Fit: [0.44101195 0.42369024 1.94818277 0.58536583]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 799.7588527832933 1.9182129785247777 1.0107981108964268
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 6.53976765e+03  1.01859149e+01  1.56183229e+00 -2.55135261e+02]
# Actin Fit: [0.72372108 0.51154159 1.98549392 0.43347092]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 791.6543983684074 1.9576594909955622 1.009251795386872
# Thickness (min) 599.0934134170342 nm
# Thickness (median) 741.5428584514908 nm
# Thickness (max) 858.0348779738441 nm
# Ransac Slope =  -4.740e-04
# Regression Slope =  -4.740e-04
# Mean Thickness (After outlier removal) =  0.747 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3a75e7f0-baad-4be5-8f85-90a36fd1672a">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="10321323-d148-4404-86cb-844b4230a0bb"></div>
# block id 9
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 8.13325185e+03  9.16316281e+00  1.45961326e+00 -3.53096714e+02]
# Actin Fit: [0.42763915 0.37183587 1.80195825 0.54026711]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 634.4361528865845 1.776831337341568 1.0358404413894993
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 9.04405694e+03  9.49713644e+00  1.47970389e+00 -3.78904178e+02]
# Actin Fit: [ 1.69113663  0.58817463  1.79424621 -0.14693079]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 585.5367469933346 1.7724722591491897 1.056610596821073
# Thickness (min) 573.8977457163004 nm
# Thickness (median) 735.7938140535971 nm
# Thickness (max) 858.0348779738441 nm
# Ransac Slope =  -7.999e-04
# Regression Slope =  -7.999e-04
# Mean Thickness (After outlier removal) =  0.731 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8f099877-498a-4fbf-8759-ebbf9459bae6">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e32a51a0-6e5f-4b8f-888e-dd2a05279835"></div>
# block id 10
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 2.07408348e+03  7.06226621e+00  1.57468340e+00 -1.16161481e+02]
# Actin Fit: [1.38677203 0.60778379 1.98231151 0.0887703 ]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 757.2179077461016 1.953292352665729 1.0140780640817764
# Time point: 10
# Membrane Fit: (Amp, Sigma, PeakPos, C) [905.1724614    5.4478705    1.57759802 -65.28392405]
# Actin Fit: [ 6.86545812  1.06909441  2.00542122 -1.56374481]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 799.6198904696893 1.9774079673527025 1.008750419385508
# Thickness (min) 573.8977457163004 nm
# Thickness (median) 733.2224291239133 nm
# Thickness (max) 858.0348779738441 nm
# Ransac Slope =  -6.137e-04
# Regression Slope =  -6.137e-04
# Mean Thickness (After outlier removal) =  0.730 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="80fad257-2bb8-41dc-b0de-4f7c53864561">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0ba555ed-a8e4-4a37-8171-0417202941bf"></div>
# CPU times: user 2min 36s, sys: 2.99 s, total: 2min 39s
# Wall time: 2min 38s

# %%
show_ransac_points_line(Thickness_time, min_samples=2, residual_threshold=0.5, max_trials=1000, Xrange = Time[-1], displayoutlier = False)
    
    

hist, edges = np.histogram((Thickness), density=False, bins='auto')
p = figure(title="Estimated Cortex Thickness = " + str('%.5f'%np.abs(edges[np.argmax(hist)] * 1000)) + 'nm', y_axis_label='Counts',x_axis_label='Thickness(um)')
listedges = edges.tolist()
listhist = hist.tolist()
output_notebook()
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
    fill_color="#036564", line_color="#033649")
for  i in range(0,len(listhist)):
  if listhist[i] > 0:
   mytext = Label(x=listedges[i], y=listhist[i], text=str('%.4f'%listedges[i]))
   p.add_layout(mytext)
show(p)
# Out:
# Ransac Slope =  -6.137e-04
# Regression Slope =  -6.137e-04
# Mean Thickness (After outlier removal) =  0.730 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09ef6431-ff77-4f92-8d45-e0e19adf4384">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d097f033-7dfd-4a2c-8fbe-8beed85d104a"></div>

# %%
master_data= []

Path(save_dir).mkdir(exist_ok = True)

for line in Thickness_time:
    master_data.append(line)
writer = csv.writer(open(save_dir + "/" + (os.path.basename(Actinimage))  +".csv", "w"))
writer.writerows(master_data)

# %%
show_plot(Thickness_time,  ymin = 0.3, ymax = 1)
