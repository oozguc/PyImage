# %%
import sys
sys.path.insert(0, "/Users/aimachine/PyImage/utils")
import numpy as np
from PIL import Image
import os
from tifffile import imread
import matplotlib.pyplot as plt
from Normalize import normalizeFloat, normalizeMinMax, Path, save_tiff_imagej_compatible
from plot_utils import singleplot, plotXY, doubleplot
from GaussFit import StripFit, Linescan
from HoughLine import show_hough_linetransform, show_ransac_points_line, show_plot, Correlation_plot,show_intensity_plot
from bokeh.models import Label
from bokeh.plotting import figure, show, output_notebook
from IPython.display import clear_output
from bokeh.models import Range1d
import csv
from GaussFit import MakePath
# Out:
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
targetdir = '/Users/aimachine/Documents/New_Folder/LineScanTest/500nmTest/'

Actinimage = '/Users/aimachine/Documents/New_Folder/LineScanTest/500nmTest/LineScanB.tif'

Membraneimage = '/Users/aimachine/Documents/New_Folder/LineScanTest/500nmTest/LineScanA.tif'


#Enter time unit in seconds
Time_unit = 1
#Enter pixel to micrometer conversion
Xcalibration = 0.068
#Enter the number of pixels to be included in the fit
Fitaround= 8

#Symmetric psf as input (micrometers)
psf = 0.17
showaftertime = 100
inisigmaguess =  psf
#Size of linescan
skip = 50
singleblock = 40 

#Number of segments
numsegments = 10
id = []
for i in range(0, numsegments):
    id.append(i)
    
MakePath(targetdir)    
save_dir = targetdir + 'ls_data'    
MakePath(save_dir)

# %%
Actin = imread(Actinimage)
Membrane = imread(Membraneimage)

doubleplot(Actin, Membrane, 'Actin Channel', 'Membrane Channel')
blockimageActin = []
blockimageMembrane = []

i = 0
while i < Actin.shape[0]:
       
   blockActin = Actin[i:i + singleblock,:]/np.amax(Actin[i:i + singleblock,:], 0)
   blockMembrane = Membrane[i:i + singleblock,:]/np.amax(Membrane[i:i + singleblock,:],0)
   
   blockimageActin.append(blockActin)
   blockimageMembrane.append(blockMembrane)
   doubleplot(blockActin, blockMembrane, 'Actin Channel', 'Membrane Channel')
   i = i + singleblock + skip 

halflength = int(len(blockimageActin)/2)
otherhalf = len(blockimageActin) - halflength
totallength = len(blockimageActin)

# %%
# %%time
#Fit all blocks

Thickness = []
Intensity = []
Time = []
for i in range(0, totallength):
 print('block id', i+1)   
 Actin = blockimageActin[i]
 Membrane = blockimageMembrane[i]
 
 StripFit(Actin, Membrane, Time_unit, Xcalibration, Fitaround, psf, inisigmaguess, showaftertime, Thickness, Intensity, Time)
 
 Correlation_plot(Thickness, Intensity)

 print("Thickness (min)",np.min(Thickness) *1000, "nm")
 print("Thickness (median)",np.median(Thickness) *1000, "nm")
 print("Thickness (max)",np.max(Thickness) *1000, "nm")
 Thickness_time = np.column_stack([Time, Thickness]) 
 Thickness_intensity = np.column_stack([Thickness, Intensity]) 
 show_ransac_points_line(Thickness_time, min_samples=2, residual_threshold=0.5, max_trials=1000, Xrange = Time[-1], displayoutlier = False)
    
    

 hist, edges = np.histogram((Thickness), density=False, bins='auto')
 p = figure(title="Estimated Cortex Thickness = " + str('%.5f'%np.abs(edges[np.argmax(hist)] * 1000)) + 'nm', y_axis_label='Counts',x_axis_label='Thickness(um)')
 listedges = edges.tolist()
 listhist = hist.tolist()
 output_notebook()
 p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
    fill_color="#036564", line_color="#033649")
 for  i in range(0,len(listhist)):
  if listhist[i] > 0:
   mytext = Label(x=listedges[i], y=listhist[i], text=str('%.4f'%listedges[i]))
   p.add_layout(mytext)
 show(p)

 #clear_output(wait = True)
# Out:
# block id 1
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [0.4292613  0.17526278 1.43858799 0.03010635]
# Actin Fit: [ 0.85687492  0.31117177  1.72708466 -0.11103803]
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/aimachine/anaconda3/envs/tensorflowpy3pt5/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/aimachine/PyImage/utils/GaussFit.py:461: RuntimeWarning: invalid value encountered in log
#   (self.actin.i_in - i_c_start  ))))
# Thickness (nm), center cortex , cortical actin intensity (from fit) 523.6557538715858 1.700415864310809 1.082443798132402
# /Users/aimachine/PyImage/utils/GaussFit.py:385: RuntimeWarning: invalid value encountered in true_divide
#   m_left = (self.i[self.left_index_right] - self.i[self.left_index_left]) /  (self.x[self.left_index_right] - self.x[self.left_index_left])
# /Users/aimachine/PyImage/utils/GaussFit.py:401: RuntimeWarning: invalid value encountered in true_divide
#   m_right = (self.i[self.right_index_right] - self.i[self.right_index_left]) / (self.x[self.right_index_right] - self.x[self.right_index_left])
# Thickness (min) 475.74741275322026 nm
# Thickness (median) 525.5157651009699 nm
# Thickness (max) 560.825911467271 nm
# Ransac Slope =  1.299e-03
# Regression Slope =  1.299e-03
# Mean Thickness (After outlier removal) =  0.524 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f87ac51c-2440-4862-bb03-b6da279eb9bd">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="889d0ec0-bc22-4311-b66a-0fe626f158b1"></div>
# block id 2
# Thickness (min) 475.74741275322026 nm
# Thickness (median) 525.5157651009699 nm
# Thickness (max) 560.825911467271 nm
# Ransac Slope =  1.299e-03
# Regression Slope =  1.299e-03
# Mean Thickness (After outlier removal) =  0.524 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9acf113b-b113-4ac5-8441-8927c8591de2">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c762ffab-7e95-467c-b4d1-6d0284ceee91"></div>
# block id 3
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [0.4228887  0.17335462 1.59902673 0.03073422]
# Actin Fit: [ 0.82251207  0.30212367  1.87895058 -0.10257371]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 527.6866538278321 1.8628700531284206 1.0845523607104808
# Thickness (min) 475.74741275322026 nm
# Thickness (median) 525.4014703921245 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  9.026e-04
# Regression Slope =  9.026e-04
# Mean Thickness (After outlier removal) =  0.526 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="89311406-9b6a-4956-9876-384fcbe0ca4d">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="03e7104d-6281-44ab-8f76-47438d454734"></div>
# block id 4
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 0.44199684  0.17027888  1.58259323 -0.04206935]
# Actin Fit: [0.29253805 0.18074854 1.82038716 0.36527374]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 453.0693631311303 1.8091279071926418 1.1814779661353267
# Thickness (min) 422.8591932939424 nm
# Thickness (median) 514.8190463505218 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  4.739e-04
# Regression Slope =  4.739e-04
# Mean Thickness (After outlier removal) =  0.509 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7e4f9e28-0646-4366-b8c9-4f0fb24ada0a">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1736dd75-17cd-42f5-95ec-b1ceaef387f9"></div>
# block id 5
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 0.4781549   0.18393859  1.56445286 -0.03084684]
# Actin Fit: [0.58813949 0.24254229 1.8134942  0.02633227]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 467.5370021058953 1.7982213627399821 1.1447250763864774
# Thickness (min) 422.8591932939424 nm
# Thickness (median) 504.4308617597293 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  4.978e-05
# Regression Slope =  4.978e-05
# Mean Thickness (After outlier removal) =  0.505 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="098e13cb-803c-4f59-aedb-c1bf558b8e57">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c4f6eb0c-fd6f-44fe-9d5d-645adba885f8"></div>
# block id 6
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 0.6094353   0.20778417  1.69595003 -0.17797607]
# Actin Fit: [ 0.71219229  0.28186178  1.99242845 -0.01247632]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 558.6398471242495 1.9752699562005724 1.0787933073172153
# Thickness (min) 422.8591932939424 nm
# Thickness (median) 509.9236487978872 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  1.195e-04
# Regression Slope =  1.195e-04
# Mean Thickness (After outlier removal) =  0.508 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e4404bb9-9515-48c1-810c-7feb615196ff">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fe704fe4-45b2-4737-948c-d00bfb1e60f0"></div>
# block id 7
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [0.38181916 0.15117319 1.593455   0.00893711]
# Actin Fit: [0.20645295 0.14607184 1.80276589 0.44670751]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 394.9070016136007 1.79090849791526 1.246889602641618
# Thickness (min) 358.0535251348761 nm
# Thickness (median) 504.4308617597293 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  1.840e-04
# Regression Slope =  1.840e-04
# Mean Thickness (After outlier removal) =  0.496 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b7715d1b-6b43-4715-86b5-2d32210ddcda">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3b9a9c13-6fe7-4991-a2a6-181e221be82a"></div>
# block id 8
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 0.52584903  0.19026455  1.85799041 -0.10473373]
# Actin Fit: [0.51140456 0.23191804 2.13849708 0.12429264]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 514.2226605823923 2.115101737414921 1.1096762514887624
# Thickness (min) 358.0535251348761 nm
# Thickness (median) 504.7109546932909 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  -2.237e-04
# Regression Slope =  -2.237e-04
# Mean Thickness (After outlier removal) =  0.496 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e9418dc2-7e6e-4324-afab-ceb38b89d26d">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0963b4dd-4700-4765-b303-a9d24fd45667"></div>
# block id 9
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [ 0.395471    0.15459959  1.81282926 -0.00978526]
# Actin Fit: [0.52187278 0.22269889 2.02659274 0.06250875]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 391.6921760554718 2.008675350781103 1.2250647010994173
# Thickness (min) 358.0535251348761 nm
# Thickness (median) 497.60551301013334 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  -2.128e-04
# Regression Slope =  -2.128e-04
# Mean Thickness (After outlier removal) =  0.488 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="14a20ef2-d4a6-45ce-93e7-632213f305d3">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="befd0b2e-8370-4216-8c2f-8ed55ef9fe4f"></div>
# block id 10
# Time point: 0
# Membrane Fit: (Amp, Sigma, PeakPos, C) [0.41113054 0.17547059 1.92514728 0.07448751]
# Actin Fit: [0.46479288 0.20705241 2.13761385 0.0930052 ]
# Thickness (nm), center cortex , cortical actin intensity (from fit) 375.91662670595207 2.1131055973230413 1.2444136637902465
# Thickness (min) 329.40514297574725 nm
# Thickness (median) 492.45916961327754 nm
# Thickness (max) 612.1120517075666 nm
# Ransac Slope =  -6.044e-04
# Regression Slope =  -6.044e-04
# Mean Thickness (After outlier removal) =  0.485 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4f185b1c-835c-4c96-97cd-7349bd91bebc">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ef840429-0105-426c-8524-da8ca1fc7087"></div>
# CPU times: user 23.5 s, sys: 349 ms, total: 23.8 s
# Wall time: 22.4 s

# %%
show_ransac_points_line(Thickness_time, min_samples=2, residual_threshold=0.5, max_trials=1000, Xrange = Time[-1], displayoutlier = False)
    
    

hist, edges = np.histogram((Thickness), density=False, bins='auto')
p = figure(title="Estimated Cortex Thickness = " + str('%.5f'%np.abs(edges[np.argmax(hist)] * 1000)) + 'nm', y_axis_label='Counts',x_axis_label='Thickness(um)')
listedges = edges.tolist()
listhist = hist.tolist()
output_notebook()
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
    fill_color="#036564", line_color="#033649")
for  i in range(0,len(listhist)):
  if listhist[i] > 0:
   mytext = Label(x=listedges[i], y=listhist[i], text=str('%.4f'%listedges[i]))
   p.add_layout(mytext)
show(p)
# Out:
# Ransac Slope =  -6.044e-04
# Regression Slope =  -6.044e-04
# Mean Thickness (After outlier removal) =  0.485 um
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="afd6a826-9832-4c69-a237-71ec84991640">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5ced0f9d-13ac-431b-bfa3-298be0571c12"></div>

# %%
master_data= []

Path(save_dir).mkdir(exist_ok = True)

for line in Thickness_time:
    master_data.append(line)
writer = csv.writer(open(save_dir + "/" + (os.path.basename(Actinimage))  +".csv", "w"))
writer.writerows(master_data)

# %%
show_plot(Thickness_time,  ymin = 0.3, ymax = 0.7)
num_clusters = 2
show_intensity_plot(Thickness_intensity, ymin = Thickness_intensity.min(), ymax = 0.8, num_clusters = num_clusters )
# Out:
# X: 1.1129771667719894 Y:  0.5123506110571873
# X: 1.1982495214903477 Y:  0.4200472335707914
