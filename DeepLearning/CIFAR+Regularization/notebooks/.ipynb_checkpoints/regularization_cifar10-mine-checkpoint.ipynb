# %% [markdown]
# # Regularization for a classifier of the cat/dog data from cifar10 dataset

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

# %%
from tensorflow.python.client import device_lib
local_device_protos = device_lib.list_local_devices()

print([x.name for x in local_device_protos if x.device_type == 'GPU'])
# Out:
# /opt/pkg/devel/python/3.6.2/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /opt/pkg/devel/python/3.6.2/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /opt/pkg/devel/python/3.6.2/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/pkg/devel/python/3.6.2/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ['/device:GPU:0']

# %%
import matplotlib.pyplot as plt

def plot_train_losses(hist):
    train_losses = hist.history['loss']
    test_losses = hist.history['val_loss']

    plt.plot(train_losses)
    plt.plot(test_losses)
    plt.title("model loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

def plot_train_accuracy(hist):
    train_acc = hist.history['acc']
    test_acc = hist.history['val_acc']

    plt.plot(train_acc)
    plt.plot(test_acc)
    plt.title("model accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
def plot_train_history(hist):
    plot_train_losses(hist)
    plot_train_accuracy(hist)

# %%
from keras.datasets import cifar10
from keras.utils import to_categorical
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, x_train.dtype, x_train.min(), x_train.max(), y_train.shape)
print(x_test.shape, x_test.dtype, x_test.min(), x_test.max(), y_test.shape)
# Out:
# (50000, 32, 32, 3) uint8 0 255 (50000, 1)
# (10000, 32, 32, 3) uint8 0 255 (10000, 1)

# %%
def only_cat_dog_data(x, y):
    # cat label is 3 and gets mapped to 0
    cats = x[np.where(y == 3)[0]]
    cats_lab = [0 for i in range(cats.shape[0])]
    
    # dog label is 5 and gets mapped to 1
    dogs = x[np.where(y == 5)[0]]
    dogs_lab = [1 for i in range(dogs.shape[0])]


    x_new = np.vstack([cats, dogs])
    y_new = np.hstack([cats_lab, dogs_lab])

    return x_new, y_new

# %%
x_tr, y_tr = only_cat_dog_data(x_train, y_train)
print(x_tr.shape, y_tr.shape)
print(y_tr[:3], y_tr[5000:5003])
# Out:
# (10000, 32, 32, 3) (10000,)
# [0 0 0] [1 1 1]

# %%
x_te, y_te = only_cat_dog_data(x_test, y_test)
print(x_te.shape, y_te.shape)
print(y_te[:3], y_te[1000:1003])
# Out:
# (2000, 32, 32, 3) (2000,)
# [0 0 0] [1 1 1]

# %%
plt.imshow(x_tr[0])
plt.show()

# %%
# use only a small fraction of x_tr for training so overfitting can be made easier
np.random.seed(42)
size_small = int(0.3 * x_tr.shape[0])  ## 0.4 worked well!

sel_idx = np.random.choice(range(x_tr.shape[0]), size=size_small, replace=False)
#print(sel_idx[:5])

x_train_small = x_tr[sel_idx]
y_train_small = y_tr[sel_idx]

print(x_train_small.shape, y_train_small.shape)
print("class 1: {}/{}".format(np.sum(y_train_small), x_train_small.shape[0]))
# Out:
# (3000, 32, 32, 3) (3000,)
# class 1: 1463/3000

# %% [markdown]
# ## Setting up the input pipeline

# %%
train_samples = x_train_small.shape[0]
test_samples = x_test.shape[0]

batch_size = 64
epochs = 30

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
)
train_generator = train_datagen.flow(x_train_small, y_train_small,
                                     batch_size=batch_size,
                                     shuffle=True)

# %%
test_datagen = ImageDataGenerator(
    rescale=1. / 255,
)
test_generator = test_datagen.flow(x_te, y_te,
                                   batch_size=batch_size,
                                   shuffle=True)

# %% [markdown]
# ## The baseline model

# %%
from keras import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPool2D

# %% [markdown]
# ### setting up the model architecture

# %%
input_shape = x_train_small.shape[1:]

def get_baseline_model_mlp():
    m_base = Sequential()
    m_base.add(Flatten(input_shape=input_shape))

    m_base.add(Dense(1024, activation="relu"))
    #m_base.add(Dense(1024, activation="relu"))
    m_base.add(Dense(512, activation="relu"))
    #m_base.add(Dense(512, activation="relu"))
    m_base.add(Dense(256, activation="relu"))
    m_base.add(Dense(128, activation="relu"))
    m_base.add(Dense(1, activation="sigmoid"))
    return m_base

def get_baseline_model_cnn():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
#m_base = get_baseline_model_mlp()
m_base = get_baseline_model_cnn()
print(m_base.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1605888
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,616,289
# Trainable params: 1,616,289
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### training the baseline model

# %%
from keras import optimizers

m_base.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               #optimizers.Adadelta(),
               "binary_crossentropy", 
               metrics=['accuracy'])

hist_base = m_base.fit_generator(train_generator,
                                 epochs=epochs,
                                 steps_per_epoch=train_samples // batch_size,
                                 validation_data=test_generator,
                                 validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 7s 148ms/step - loss: 0.6886 - acc: 0.5368 - val_loss: 0.6856 - val_acc: 0.5536
# Epoch 2/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6705 - acc: 0.5905 - val_loss: 0.6675 - val_acc: 0.5950
# Epoch 3/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6620 - acc: 0.6051 - val_loss: 0.6675 - val_acc: 0.5908
# Epoch 4/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6501 - acc: 0.6237 - val_loss: 0.6742 - val_acc: 0.5744
# Epoch 5/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6516 - acc: 0.6200 - val_loss: 0.6589 - val_acc: 0.6091
# Epoch 6/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6387 - acc: 0.6389 - val_loss: 0.6542 - val_acc: 0.6108
# Epoch 7/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6320 - acc: 0.6510 - val_loss: 0.6714 - val_acc: 0.6032
# Epoch 8/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6224 - acc: 0.6566 - val_loss: 0.6458 - val_acc: 0.6268
# Epoch 9/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6081 - acc: 0.6707 - val_loss: 0.6400 - val_acc: 0.6309
# Epoch 10/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5888 - acc: 0.6880 - val_loss: 0.6398 - val_acc: 0.6520
# Epoch 11/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5743 - acc: 0.7055 - val_loss: 0.6678 - val_acc: 0.6331
# Epoch 12/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5574 - acc: 0.7160 - val_loss: 0.6189 - val_acc: 0.6644
# Epoch 13/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5464 - acc: 0.7335 - val_loss: 0.6171 - val_acc: 0.6616
# Epoch 14/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5094 - acc: 0.7526 - val_loss: 0.6265 - val_acc: 0.6743
# Epoch 15/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5019 - acc: 0.7562 - val_loss: 0.6237 - val_acc: 0.6732
# Epoch 16/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.4473 - acc: 0.7923 - val_loss: 0.6469 - val_acc: 0.6670
# Epoch 17/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.4190 - acc: 0.8164 - val_loss: 0.6797 - val_acc: 0.6550
# Epoch 18/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3801 - acc: 0.8404 - val_loss: 0.7129 - val_acc: 0.6691
# Epoch 19/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3280 - acc: 0.8667 - val_loss: 0.7485 - val_acc: 0.6643
# Epoch 20/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.2802 - acc: 0.8903 - val_loss: 0.7876 - val_acc: 0.6617
# Epoch 21/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.2234 - acc: 0.9223 - val_loss: 0.8327 - val_acc: 0.6681
# Epoch 22/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.1516 - acc: 0.9555 - val_loss: 0.8989 - val_acc: 0.6719
# Epoch 23/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.1038 - acc: 0.9728 - val_loss: 0.9768 - val_acc: 0.6717
# Epoch 24/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0736 - acc: 0.9843 - val_loss: 1.0410 - val_acc: 0.6775
# Epoch 25/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0429 - acc: 0.9925 - val_loss: 1.1713 - val_acc: 0.6681
# Epoch 26/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0217 - acc: 0.9990 - val_loss: 1.2042 - val_acc: 0.6730
# Epoch 27/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0116 - acc: 0.9997 - val_loss: 1.2545 - val_acc: 0.6751
# Epoch 28/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0075 - acc: 1.0000 - val_loss: 1.3088 - val_acc: 0.6775
# Epoch 29/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 1.3409 - val_acc: 0.6798
# Epoch 30/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 1.3636 - val_acc: 0.6759

# %%
plot_train_history(hist_base)

# %% [markdown]
# ## Using "early stopping"

# %%
# reset batch_size to original value
batch_size = 64

from keras.callbacks import EarlyStopping

m_base = get_baseline_model_cnn()

m_base.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               #optimizers.Adadelta(),
               "binary_crossentropy", 
               metrics=['accuracy'])

hist_earlystop = m_base.fit_generator(train_generator,
                                      epochs=epochs,
                                      steps_per_epoch=train_samples // batch_size,
                                      validation_data=test_generator,
                                      validation_steps=test_samples // batch_size,
                                      callbacks=[
                                          EarlyStopping(monitor='val_loss', min_delta=0.1, patience=15, verbose=1)])
# Out:
# Epoch 1/30
# 46/46 [==============================] - 2s 43ms/step - loss: 0.6907 - acc: 0.5363 - val_loss: 0.6817 - val_acc: 0.5881
# Epoch 2/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6708 - acc: 0.5936 - val_loss: 0.6827 - val_acc: 0.5785
# Epoch 3/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6597 - acc: 0.6043 - val_loss: 0.6650 - val_acc: 0.5858
# Epoch 4/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6439 - acc: 0.6365 - val_loss: 0.6738 - val_acc: 0.5833
# Epoch 5/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6297 - acc: 0.6496 - val_loss: 0.6554 - val_acc: 0.6134
# Epoch 6/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6208 - acc: 0.6598 - val_loss: 0.6802 - val_acc: 0.6037
# Epoch 7/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5986 - acc: 0.6890 - val_loss: 0.6507 - val_acc: 0.6325
# Epoch 8/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5837 - acc: 0.6868 - val_loss: 0.6391 - val_acc: 0.6456
# Epoch 9/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5648 - acc: 0.7080 - val_loss: 0.6497 - val_acc: 0.6441
# Epoch 10/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5561 - acc: 0.7126 - val_loss: 0.6488 - val_acc: 0.6374
# Epoch 11/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5241 - acc: 0.7382 - val_loss: 0.6276 - val_acc: 0.6679
# Epoch 12/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5128 - acc: 0.7565 - val_loss: 0.6147 - val_acc: 0.6732
# Epoch 13/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.4601 - acc: 0.7850 - val_loss: 0.6738 - val_acc: 0.6500
# Epoch 14/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.4388 - acc: 0.7972 - val_loss: 0.6216 - val_acc: 0.6796
# Epoch 15/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3902 - acc: 0.8299 - val_loss: 0.7377 - val_acc: 0.6501
# Epoch 16/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3528 - acc: 0.8476 - val_loss: 0.6665 - val_acc: 0.6666
# Epoch 00016: early stopping

# %%
plot_train_history(hist_earlystop)

# %% [markdown]
# ## Using L1 regularization

# %%
# copy-paste the baseline model, but add regularization terms to each layer
from keras import regularizers

reg_weight = 1.e-4

def get_l1_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', 
                     kernel_regularizer=regularizers.l1(reg_weight), input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu',
                     kernel_regularizer=regularizers.l1(reg_weight)))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu',
                    kernel_regularizer=regularizers.l1(reg_weight)))
    model.add(Dense(1, activation='sigmoid',
                    kernel_regularizer=regularizers.l1(reg_weight)))
    
    return model

# %%
m_l1 = get_l1_model()

m_l1.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               #optimizers.Adadelta(),
               "binary_crossentropy", 
               metrics=['accuracy'])

hist_l1 = m_l1.fit_generator(train_generator,
                             epochs=epochs,
                             steps_per_epoch=train_samples // batch_size,
                             validation_data=test_generator,
                             validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 2s 48ms/step - loss: 3.1517 - acc: 0.5479 - val_loss: 3.1099 - val_acc: 0.5686
# Epoch 2/30
# 46/46 [==============================] - 2s 39ms/step - loss: 3.0635 - acc: 0.5959 - val_loss: 3.0241 - val_acc: 0.5958
# Epoch 3/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.9832 - acc: 0.6034 - val_loss: 2.9529 - val_acc: 0.5941
# Epoch 4/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.9010 - acc: 0.6218 - val_loss: 2.8751 - val_acc: 0.5983
# Epoch 5/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.8280 - acc: 0.6308 - val_loss: 2.8024 - val_acc: 0.6115
# Epoch 6/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.7446 - acc: 0.6518 - val_loss: 2.7403 - val_acc: 0.6075
# Epoch 7/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.6627 - acc: 0.6594 - val_loss: 2.6582 - val_acc: 0.6382
# Epoch 8/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.5870 - acc: 0.6702 - val_loss: 2.5817 - val_acc: 0.6506
# Epoch 9/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.5095 - acc: 0.6821 - val_loss: 2.5089 - val_acc: 0.6625
# Epoch 10/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.4350 - acc: 0.6914 - val_loss: 2.4407 - val_acc: 0.6565
# Epoch 11/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.3518 - acc: 0.7110 - val_loss: 2.4052 - val_acc: 0.6449
# Epoch 12/30
# 46/46 [==============================] - 2s 39ms/step - loss: 2.2795 - acc: 0.7192 - val_loss: 2.3124 - val_acc: 0.6673
# Epoch 13/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.2041 - acc: 0.7351 - val_loss: 2.2897 - val_acc: 0.6528
# Epoch 14/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.1360 - acc: 0.7401 - val_loss: 2.2016 - val_acc: 0.6626
# Epoch 15/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.0420 - acc: 0.7717 - val_loss: 2.1492 - val_acc: 0.6727
# Epoch 16/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.9755 - acc: 0.7766 - val_loss: 2.0974 - val_acc: 0.6683
# Epoch 17/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.8829 - acc: 0.8096 - val_loss: 2.0747 - val_acc: 0.6766
# Epoch 18/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.7953 - acc: 0.8287 - val_loss: 2.0844 - val_acc: 0.6605
# Epoch 19/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.7102 - acc: 0.8521 - val_loss: 2.0745 - val_acc: 0.6562
# Epoch 20/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.6125 - acc: 0.8826 - val_loss: 2.0438 - val_acc: 0.6600
# Epoch 21/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.5383 - acc: 0.8965 - val_loss: 1.9921 - val_acc: 0.6714
# Epoch 22/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.4415 - acc: 0.9271 - val_loss: 2.0112 - val_acc: 0.6765
# Epoch 23/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.3495 - acc: 0.9466 - val_loss: 2.0196 - val_acc: 0.6746
# Epoch 24/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.2756 - acc: 0.9623 - val_loss: 2.2026 - val_acc: 0.6465
# Epoch 25/30
# 46/46 [==============================] - 2s 39ms/step - loss: 1.1920 - acc: 0.9829 - val_loss: 2.1508 - val_acc: 0.6700
# Epoch 26/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.1439 - acc: 0.9800 - val_loss: 2.0781 - val_acc: 0.6806
# Epoch 27/30
# 46/46 [==============================] - 2s 39ms/step - loss: 1.0672 - acc: 0.9949 - val_loss: 2.1192 - val_acc: 0.6784
# Epoch 28/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.0071 - acc: 0.9983 - val_loss: 2.1009 - val_acc: 0.6841
# Epoch 29/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.9531 - acc: 0.9997 - val_loss: 2.0929 - val_acc: 0.6833
# Epoch 30/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.9051 - acc: 0.9997 - val_loss: 2.0648 - val_acc: 0.6848

# %%
plot_train_history(hist_l1)

# %% [markdown]
# ## Using L2 regularization

# %%
# copy-paste the baseline model, but add regularization terms to each layer
from keras import regularizers

reg_weight = 1.e-4

def get_l2_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', 
                     kernel_regularizer=regularizers.l2(reg_weight), input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu',
                     kernel_regularizer=regularizers.l2(reg_weight)))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu',
                    kernel_regularizer=regularizers.l2(reg_weight)))
    model.add(Dense(1, activation='sigmoid',
                    kernel_regularizer=regularizers.l2(reg_weight)))
    return model

# %%
m_l2 = get_l2_model()

m_l2.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               #optimizers.Adadelta(),
               "binary_crossentropy", 
               metrics=['accuracy'])

hist_l2 = m_l2.fit_generator(train_generator,
                             epochs=epochs,
                             steps_per_epoch=train_samples // batch_size,
                             validation_data=test_generator,
                             validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 5s 111ms/step - loss: 0.7367 - acc: 0.5600 - val_loss: 0.7262 - val_acc: 0.5671
# Epoch 2/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.7191 - acc: 0.5891 - val_loss: 0.7347 - val_acc: 0.5779
# Epoch 3/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.7080 - acc: 0.6129 - val_loss: 0.7168 - val_acc: 0.5950
# Epoch 4/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6984 - acc: 0.6267 - val_loss: 0.7112 - val_acc: 0.6052
# Epoch 5/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6871 - acc: 0.6361 - val_loss: 0.7399 - val_acc: 0.5917
# Epoch 6/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6818 - acc: 0.6473 - val_loss: 0.7078 - val_acc: 0.6258
# Epoch 7/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6649 - acc: 0.6631 - val_loss: 0.7074 - val_acc: 0.6187
# Epoch 8/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6648 - acc: 0.6626 - val_loss: 0.6889 - val_acc: 0.6513
# Epoch 9/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6362 - acc: 0.7001 - val_loss: 0.6882 - val_acc: 0.6489
# Epoch 10/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6226 - acc: 0.7189 - val_loss: 0.7138 - val_acc: 0.6377
# Epoch 11/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6147 - acc: 0.7181 - val_loss: 0.6892 - val_acc: 0.6473
# Epoch 12/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5918 - acc: 0.7366 - val_loss: 0.6786 - val_acc: 0.6640
# Epoch 13/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5599 - acc: 0.7516 - val_loss: 0.6877 - val_acc: 0.6638
# Epoch 14/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.5322 - acc: 0.7731 - val_loss: 0.6884 - val_acc: 0.6588
# Epoch 15/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.4966 - acc: 0.7943 - val_loss: 0.6777 - val_acc: 0.6649
# Epoch 16/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4686 - acc: 0.8192 - val_loss: 0.7762 - val_acc: 0.6373
# Epoch 17/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4429 - acc: 0.8422 - val_loss: 0.7323 - val_acc: 0.6680
# Epoch 18/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.3622 - acc: 0.8696 - val_loss: 0.7218 - val_acc: 0.6780
# Epoch 19/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.3151 - acc: 0.9070 - val_loss: 0.8231 - val_acc: 0.6721
# Epoch 20/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.2444 - acc: 0.9346 - val_loss: 0.8445 - val_acc: 0.6733
# Epoch 21/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.2117 - acc: 0.9496 - val_loss: 0.9069 - val_acc: 0.6763
# Epoch 22/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1704 - acc: 0.9695 - val_loss: 1.0014 - val_acc: 0.6724
# Epoch 23/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1185 - acc: 0.9878 - val_loss: 1.0127 - val_acc: 0.6830
# Epoch 24/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1005 - acc: 0.9925 - val_loss: 1.1695 - val_acc: 0.6683
# Epoch 25/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0800 - acc: 0.9986 - val_loss: 1.2315 - val_acc: 0.6765
# Epoch 26/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0691 - acc: 1.0000 - val_loss: 1.3241 - val_acc: 0.6745
# Epoch 27/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0643 - acc: 1.0000 - val_loss: 1.3653 - val_acc: 0.6745
# Epoch 28/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0619 - acc: 1.0000 - val_loss: 1.3714 - val_acc: 0.6761
# Epoch 29/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0608 - acc: 1.0000 - val_loss: 1.4125 - val_acc: 0.6736
# Epoch 30/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0600 - acc: 1.0000 - val_loss: 1.4314 - val_acc: 0.6741

# %%
plot_train_history(hist_l2)

# %% [markdown]
# ## Using L1 and L2 regularization

# %%
reg_weight = 1.e-4

def get_l1_l2_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', 
                     kernel_regularizer=regularizers.l1_l2(reg_weight, reg_weight), input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu',
                     kernel_regularizer=regularizers.l1_l2(reg_weight, reg_weight)))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu',
                    kernel_regularizer=regularizers.l1_l2(reg_weight, reg_weight)))
    model.add(Dense(1, activation='sigmoid',
                    kernel_regularizer=regularizers.l1_l2(reg_weight, reg_weight)))
    return model

# %%
m_l1l2 = get_l1_l2_model()

m_l1l2.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               #optimizers.Adadelta(),
               "binary_crossentropy", 
               metrics=['accuracy'])

hist_l1l2 = m_l1l2.fit_generator(train_generator,
                                 epochs=epochs,
                                 steps_per_epoch=train_samples // batch_size,
                                 validation_data=test_generator,
                                 validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 3s 55ms/step - loss: 3.2018 - acc: 0.5394 - val_loss: 3.1578 - val_acc: 0.5413
# Epoch 2/30
# 46/46 [==============================] - 2s 41ms/step - loss: 3.1108 - acc: 0.5845 - val_loss: 3.0702 - val_acc: 0.5948
# Epoch 3/30
# 46/46 [==============================] - 2s 40ms/step - loss: 3.0178 - acc: 0.6197 - val_loss: 2.9959 - val_acc: 0.5689
# Epoch 4/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.9434 - acc: 0.6137 - val_loss: 2.9166 - val_acc: 0.5954
# Epoch 5/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.8552 - acc: 0.6315 - val_loss: 2.8546 - val_acc: 0.5974
# Epoch 6/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.7695 - acc: 0.6590 - val_loss: 2.7609 - val_acc: 0.6167
# Epoch 7/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.6908 - acc: 0.6613 - val_loss: 2.6884 - val_acc: 0.6181
# Epoch 8/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.6145 - acc: 0.6609 - val_loss: 2.6156 - val_acc: 0.6259
# Epoch 9/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.5280 - acc: 0.6935 - val_loss: 2.5343 - val_acc: 0.6505
# Epoch 10/30
# 46/46 [==============================] - 2s 41ms/step - loss: 2.4409 - acc: 0.6978 - val_loss: 2.4752 - val_acc: 0.6543
# Epoch 11/30
# 46/46 [==============================] - 2s 40ms/step - loss: 2.3623 - acc: 0.7160 - val_loss: 2.4022 - val_acc: 0.6557
# Epoch 12/30
# 46/46 [==============================] - 2s 41ms/step - loss: 2.2734 - acc: 0.7351 - val_loss: 2.3498 - val_acc: 0.6436
# Epoch 13/30
# 46/46 [==============================] - 2s 41ms/step - loss: 2.2032 - acc: 0.7448 - val_loss: 2.2844 - val_acc: 0.6483
# Epoch 14/30
# 46/46 [==============================] - 2s 41ms/step - loss: 2.1135 - acc: 0.7599 - val_loss: 2.2215 - val_acc: 0.6669
# Epoch 15/30
# 46/46 [==============================] - 2s 41ms/step - loss: 2.0330 - acc: 0.7805 - val_loss: 2.1607 - val_acc: 0.6718
# Epoch 16/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.9489 - acc: 0.7993 - val_loss: 2.1155 - val_acc: 0.6624
# Epoch 17/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.8668 - acc: 0.8183 - val_loss: 2.0885 - val_acc: 0.6539
# Epoch 18/30
# 46/46 [==============================] - 2s 42ms/step - loss: 1.7846 - acc: 0.8315 - val_loss: 2.0640 - val_acc: 0.6573
# Epoch 19/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.6993 - acc: 0.8537 - val_loss: 2.0074 - val_acc: 0.6688
# Epoch 20/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.6154 - acc: 0.8817 - val_loss: 2.0096 - val_acc: 0.6618
# Epoch 21/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.5181 - acc: 0.9084 - val_loss: 2.0378 - val_acc: 0.6536
# Epoch 22/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.4322 - acc: 0.9271 - val_loss: 2.0391 - val_acc: 0.6552
# Epoch 23/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.3527 - acc: 0.9381 - val_loss: 2.0787 - val_acc: 0.6651
# Epoch 24/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.3338 - acc: 0.9333 - val_loss: 2.0355 - val_acc: 0.6614
# Epoch 25/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.2064 - acc: 0.9704 - val_loss: 2.1144 - val_acc: 0.6580
# Epoch 26/30
# 46/46 [==============================] - 2s 41ms/step - loss: 1.1285 - acc: 0.9863 - val_loss: 2.0937 - val_acc: 0.6632
# Epoch 27/30
# 46/46 [==============================] - 2s 40ms/step - loss: 1.0504 - acc: 0.9966 - val_loss: 2.1101 - val_acc: 0.6701
# Epoch 28/30
# 46/46 [==============================] - 2s 41ms/step - loss: 0.9902 - acc: 0.9990 - val_loss: 2.1105 - val_acc: 0.6597
# Epoch 29/30
# 46/46 [==============================] - 2s 41ms/step - loss: 0.9401 - acc: 0.9997 - val_loss: 2.1011 - val_acc: 0.6646
# Epoch 30/30
# 46/46 [==============================] - 2s 41ms/step - loss: 0.8944 - acc: 0.9990 - val_loss: 2.0455 - val_acc: 0.6598

# %%
plot_train_history(hist_l1l2)

# %% [markdown]
# ## Using dropout

# %%
from keras.layers import Dropout

def get_dropout_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %%
m_drop = get_dropout_model()

m_drop.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               #optimizers.Adadelta(),
               "binary_crossentropy", 
               metrics=['accuracy'])

hist_drop = m_drop.fit_generator(train_generator,
                                 epochs=epochs,
                                 steps_per_epoch=train_samples // batch_size,
                                 validation_data=test_generator,
                                 validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 2s 49ms/step - loss: 0.6963 - acc: 0.5237 - val_loss: 0.6829 - val_acc: 0.5921
# Epoch 2/30
# 46/46 [==============================] - 2s 39ms/step - loss: 0.6820 - acc: 0.5624 - val_loss: 0.6735 - val_acc: 0.5972
# Epoch 3/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6744 - acc: 0.5845 - val_loss: 0.6710 - val_acc: 0.6041
# Epoch 4/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6672 - acc: 0.6114 - val_loss: 0.6615 - val_acc: 0.6001
# Epoch 5/30
# 46/46 [==============================] - 2s 41ms/step - loss: 0.6598 - acc: 0.6050 - val_loss: 0.6575 - val_acc: 0.6120
# Epoch 6/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6587 - acc: 0.6178 - val_loss: 0.6661 - val_acc: 0.6011
# Epoch 7/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6476 - acc: 0.6325 - val_loss: 0.6551 - val_acc: 0.6211
# Epoch 8/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6449 - acc: 0.6332 - val_loss: 0.6428 - val_acc: 0.6450
# Epoch 9/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6322 - acc: 0.6427 - val_loss: 0.6404 - val_acc: 0.6428
# Epoch 10/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6286 - acc: 0.6439 - val_loss: 0.6349 - val_acc: 0.6409
# Epoch 11/30
# 46/46 [==============================] - 2s 41ms/step - loss: 0.6161 - acc: 0.6536 - val_loss: 0.6239 - val_acc: 0.6628
# Epoch 12/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6088 - acc: 0.6688 - val_loss: 0.6192 - val_acc: 0.6628
# Epoch 13/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5981 - acc: 0.6840 - val_loss: 0.6121 - val_acc: 0.6625
# Epoch 14/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.6007 - acc: 0.6696 - val_loss: 0.6194 - val_acc: 0.6637
# Epoch 15/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5935 - acc: 0.6906 - val_loss: 0.6224 - val_acc: 0.6649
# Epoch 16/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5789 - acc: 0.6986 - val_loss: 0.6072 - val_acc: 0.6744
# Epoch 17/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5725 - acc: 0.7035 - val_loss: 0.6150 - val_acc: 0.6687
# Epoch 18/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5652 - acc: 0.7067 - val_loss: 0.6133 - val_acc: 0.6558
# Epoch 19/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5618 - acc: 0.7089 - val_loss: 0.5992 - val_acc: 0.6778
# Epoch 20/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5355 - acc: 0.7357 - val_loss: 0.5980 - val_acc: 0.6825
# Epoch 21/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5384 - acc: 0.7339 - val_loss: 0.6046 - val_acc: 0.6796
# Epoch 22/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5276 - acc: 0.7443 - val_loss: 0.5918 - val_acc: 0.6806
# Epoch 23/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5198 - acc: 0.7347 - val_loss: 0.5978 - val_acc: 0.6814
# Epoch 24/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4990 - acc: 0.7491 - val_loss: 0.6147 - val_acc: 0.6691
# Epoch 25/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.5092 - acc: 0.7470 - val_loss: 0.5920 - val_acc: 0.6816
# Epoch 26/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4878 - acc: 0.7567 - val_loss: 0.5887 - val_acc: 0.6901
# Epoch 27/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4587 - acc: 0.7747 - val_loss: 0.5957 - val_acc: 0.6870
# Epoch 28/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4660 - acc: 0.7894 - val_loss: 0.5944 - val_acc: 0.6918
# Epoch 29/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4527 - acc: 0.7875 - val_loss: 0.5854 - val_acc: 0.6911
# Epoch 30/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.4417 - acc: 0.7972 - val_loss: 0.5937 - val_acc: 0.6870

# %%
plot_train_history(hist_drop)

# %% [markdown]
# ## Using batch normalization

# %%
from keras.layers import BatchNormalization

# TODO: batch norm after relu okay?
def get_batchnorm_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %%
m_bn = get_batchnorm_model()

m_bn.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
             "binary_crossentropy", 
             metrics=['accuracy'])

hist_bn = m_bn.fit_generator(train_generator,
                             epochs=epochs,
                             steps_per_epoch=train_samples // batch_size,
                             validation_data=test_generator,
                             validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 3s 57ms/step - loss: 0.7661 - acc: 0.5794 - val_loss: 0.8312 - val_acc: 0.5535
# Epoch 2/30
# 46/46 [==============================] - 2s 45ms/step - loss: 0.6405 - acc: 0.6320 - val_loss: 0.9755 - val_acc: 0.5137
# Epoch 3/30
# 46/46 [==============================] - 2s 45ms/step - loss: 0.6028 - acc: 0.6689 - val_loss: 0.8019 - val_acc: 0.5623
# Epoch 4/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.5746 - acc: 0.6980 - val_loss: 0.8421 - val_acc: 0.5558
# Epoch 5/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.5427 - acc: 0.7293 - val_loss: 0.8556 - val_acc: 0.5674
# Epoch 6/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.4701 - acc: 0.7778 - val_loss: 2.0362 - val_acc: 0.5098
# Epoch 7/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3982 - acc: 0.8201 - val_loss: 0.9797 - val_acc: 0.5932
# Epoch 8/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3089 - acc: 0.8761 - val_loss: 0.8498 - val_acc: 0.6360
# Epoch 9/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2174 - acc: 0.9180 - val_loss: 0.8699 - val_acc: 0.6271
# Epoch 10/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.1368 - acc: 0.9581 - val_loss: 1.0607 - val_acc: 0.5984
# Epoch 11/30
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0912 - acc: 0.9745 - val_loss: 1.1265 - val_acc: 0.6369
# Epoch 12/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0554 - acc: 0.9894 - val_loss: 1.3339 - val_acc: 0.6313
# Epoch 13/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0331 - acc: 0.9959 - val_loss: 1.1938 - val_acc: 0.6465
# Epoch 14/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0153 - acc: 0.9990 - val_loss: 1.1319 - val_acc: 0.6527
# Epoch 15/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0097 - acc: 1.0000 - val_loss: 1.1817 - val_acc: 0.6521
# Epoch 16/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 1.2424 - val_acc: 0.6607
# Epoch 17/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0067 - acc: 1.0000 - val_loss: 1.2109 - val_acc: 0.6555
# Epoch 18/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 1.2523 - val_acc: 0.6599
# Epoch 19/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 1.2846 - val_acc: 0.6616
# Epoch 20/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.2499 - val_acc: 0.6606
# Epoch 21/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 1.2603 - val_acc: 0.6616
# Epoch 22/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 1.2791 - val_acc: 0.6637
# Epoch 23/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.3041 - val_acc: 0.6661
# Epoch 24/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.3060 - val_acc: 0.6651
# Epoch 25/30
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.3160 - val_acc: 0.6584
# Epoch 26/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.3326 - val_acc: 0.6635
# Epoch 27/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.3211 - val_acc: 0.6610
# Epoch 28/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.3634 - val_acc: 0.6612
# Epoch 29/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.3674 - val_acc: 0.6641
# Epoch 30/30
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.3706 - val_acc: 0.6682

# %%
plot_train_history(hist_bn)

# %% [markdown]
# ## Using data augmentation

# %%
# now we need to set up a different input pipeline that does the augmentation for us
train_datagen_aug = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=45,
    shear_range=0.2,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')

train_generator_aug = train_datagen_aug.flow(x_train_small, y_train_small,
                                             batch_size=batch_size,
                                             shuffle=True)

# %%
# plot some augmented images
img_batch, label_batch = train_generator_aug.next()
for i in range(5):
    plt.imshow(img_batch[i])
    plt.title("class " + str(label_batch[i]))
    plt.show()

# %%
# during validation we do NOT augment the images of course
test_datagen_aug = ImageDataGenerator(
    rescale=1. / 255,
)
test_generator_aug = test_datagen_aug.flow(x_te, y_te,
                                   batch_size=batch_size,
                                   shuffle=True)

# %%
m_base = get_baseline_model_cnn()

m_base.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
               "binary_crossentropy", 
               metrics=['accuracy'])


hist_aug = m_base.fit_generator(train_generator_aug,
                                epochs=epochs,
                                steps_per_epoch=train_samples // batch_size,
                                validation_data=test_generator_aug,
                                validation_steps=test_samples // batch_size)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 3s 73ms/step - loss: 0.6910 - acc: 0.5284 - val_loss: 0.6816 - val_acc: 0.5720
# Epoch 2/30
# 46/46 [==============================] - 3s 72ms/step - loss: 0.6859 - acc: 0.5513 - val_loss: 0.6778 - val_acc: 0.5834
# Epoch 3/30
# 46/46 [==============================] - 3s 70ms/step - loss: 0.6860 - acc: 0.5482 - val_loss: 0.6759 - val_acc: 0.5821
# Epoch 4/30
# 46/46 [==============================] - 3s 70ms/step - loss: 0.6837 - acc: 0.5687 - val_loss: 0.6737 - val_acc: 0.5893
# Epoch 5/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6776 - acc: 0.5767 - val_loss: 0.6676 - val_acc: 0.5985
# Epoch 6/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6790 - acc: 0.5696 - val_loss: 0.6679 - val_acc: 0.5817
# Epoch 7/30
# 46/46 [==============================] - 3s 69ms/step - loss: 0.6809 - acc: 0.5652 - val_loss: 0.6701 - val_acc: 0.5985
# Epoch 8/30
# 46/46 [==============================] - 3s 70ms/step - loss: 0.6751 - acc: 0.5961 - val_loss: 0.6758 - val_acc: 0.5852
# Epoch 9/30
# 46/46 [==============================] - 3s 69ms/step - loss: 0.6752 - acc: 0.5831 - val_loss: 0.6573 - val_acc: 0.6123
# Epoch 10/30
# 46/46 [==============================] - 3s 68ms/step - loss: 0.6757 - acc: 0.5789 - val_loss: 0.6596 - val_acc: 0.5871
# Epoch 11/30
# 46/46 [==============================] - 3s 70ms/step - loss: 0.6662 - acc: 0.5958 - val_loss: 0.6499 - val_acc: 0.6290
# Epoch 12/30
# 46/46 [==============================] - 3s 69ms/step - loss: 0.6682 - acc: 0.5876 - val_loss: 0.6452 - val_acc: 0.6311
# Epoch 13/30
# 46/46 [==============================] - 3s 67ms/step - loss: 0.6625 - acc: 0.5986 - val_loss: 0.6363 - val_acc: 0.6364
# Epoch 14/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6607 - acc: 0.6038 - val_loss: 0.6328 - val_acc: 0.6457
# Epoch 15/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6574 - acc: 0.6155 - val_loss: 0.6269 - val_acc: 0.6577
# Epoch 16/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6573 - acc: 0.6112 - val_loss: 0.6327 - val_acc: 0.6495
# Epoch 17/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6505 - acc: 0.6151 - val_loss: 0.6472 - val_acc: 0.6285
# Epoch 18/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6628 - acc: 0.6020 - val_loss: 0.6366 - val_acc: 0.6439
# Epoch 19/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6491 - acc: 0.6243 - val_loss: 0.6280 - val_acc: 0.6448
# Epoch 20/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6506 - acc: 0.6194 - val_loss: 0.6276 - val_acc: 0.6555
# Epoch 21/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6523 - acc: 0.6182 - val_loss: 0.6219 - val_acc: 0.6582
# Epoch 22/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6438 - acc: 0.6247 - val_loss: 0.6249 - val_acc: 0.6517
# Epoch 23/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6536 - acc: 0.6199 - val_loss: 0.6347 - val_acc: 0.6302
# Epoch 24/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6461 - acc: 0.6240 - val_loss: 0.6168 - val_acc: 0.6598
# Epoch 25/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6427 - acc: 0.6291 - val_loss: 0.6361 - val_acc: 0.6376
# Epoch 26/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6482 - acc: 0.6281 - val_loss: 0.6244 - val_acc: 0.6444
# Epoch 27/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6400 - acc: 0.6351 - val_loss: 0.6165 - val_acc: 0.6652
# Epoch 28/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6486 - acc: 0.6233 - val_loss: 0.6115 - val_acc: 0.6678
# Epoch 29/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6380 - acc: 0.6384 - val_loss: 0.6106 - val_acc: 0.6610
# Epoch 30/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6393 - acc: 0.6345 - val_loss: 0.6062 - val_acc: 0.6759

# %%
plot_train_history(hist_aug)

# %% [markdown]
# ## Putting the things that worked together: EarlyStopping, Dropout, BatchNorm and Data augmentation

# %%
def get_regularized_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    #model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.15))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    #model.add(BatchNormalization())
    model.add(Dropout(0.15))
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %%
m_reg = get_regularized_model()

m_reg.compile(optimizers.SGD(lr=0.01, momentum=0.9, decay=1.e-6, nesterov=True),
                "binary_crossentropy", 
                metrics=['accuracy'])

hist_reg = m_reg.fit_generator(train_generator_aug,
                             epochs=epochs,
                             steps_per_epoch=train_samples // batch_size,
                             validation_data=test_generator_aug,
                             validation_steps=test_samples // batch_size,
                              callbacks=[
                                  EarlyStopping(monitor='val_loss', min_delta=0.01, patience=25, verbose=1)])
# Out:
# Epoch 1/30
# 46/46 [==============================] - 3s 74ms/step - loss: 0.6935 - acc: 0.5231 - val_loss: 0.6837 - val_acc: 0.5498
# Epoch 2/30
# 46/46 [==============================] - 3s 72ms/step - loss: 0.6867 - acc: 0.5488 - val_loss: 0.6795 - val_acc: 0.5760
# Epoch 3/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6886 - acc: 0.5476 - val_loss: 0.6824 - val_acc: 0.5681
# Epoch 4/30
# 46/46 [==============================] - 3s 70ms/step - loss: 0.6850 - acc: 0.5549 - val_loss: 0.6738 - val_acc: 0.5873
# Epoch 5/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6832 - acc: 0.5584 - val_loss: 0.6715 - val_acc: 0.5768
# Epoch 6/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6831 - acc: 0.5720 - val_loss: 0.6704 - val_acc: 0.5894
# Epoch 7/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6758 - acc: 0.5796 - val_loss: 0.6666 - val_acc: 0.5844
# Epoch 8/30
# 46/46 [==============================] - 3s 71ms/step - loss: 0.6807 - acc: 0.5613 - val_loss: 0.6786 - val_acc: 0.6052
# Epoch 9/30
# 46/46 [==============================] - 3s 67ms/step - loss: 0.6804 - acc: 0.5729 - val_loss: 0.6644 - val_acc: 0.5956
# Epoch 10/30
# 46/46 [==============================] - 3s 70ms/step - loss: 0.6777 - acc: 0.5735 - val_loss: 0.6639 - val_acc: 0.5960
# Epoch 11/30
# 46/46 [==============================] - 3s 68ms/step - loss: 0.6784 - acc: 0.5782 - val_loss: 0.6683 - val_acc: 0.6031
# Epoch 12/30
# 46/46 [==============================] - 3s 68ms/step - loss: 0.6767 - acc: 0.5694 - val_loss: 0.6616 - val_acc: 0.6084
# Epoch 13/30
# 46/46 [==============================] - 3s 67ms/step - loss: 0.6756 - acc: 0.5921 - val_loss: 0.6581 - val_acc: 0.6065
# Epoch 14/30
# 46/46 [==============================] - 3s 67ms/step - loss: 0.6715 - acc: 0.5898 - val_loss: 0.6540 - val_acc: 0.6198
# Epoch 15/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6729 - acc: 0.5887 - val_loss: 0.6548 - val_acc: 0.6167
# Epoch 16/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6649 - acc: 0.5954 - val_loss: 0.6521 - val_acc: 0.6061
# Epoch 17/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6709 - acc: 0.5872 - val_loss: 0.6485 - val_acc: 0.6235
# Epoch 18/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6718 - acc: 0.5846 - val_loss: 0.6570 - val_acc: 0.6139
# Epoch 19/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6698 - acc: 0.5880 - val_loss: 0.6583 - val_acc: 0.5946
# Epoch 20/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6711 - acc: 0.5853 - val_loss: 0.6483 - val_acc: 0.6290
# Epoch 21/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6674 - acc: 0.5996 - val_loss: 0.6406 - val_acc: 0.6305
# Epoch 22/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6658 - acc: 0.5873 - val_loss: 0.6379 - val_acc: 0.6472
# Epoch 23/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6592 - acc: 0.6019 - val_loss: 0.6364 - val_acc: 0.6398
# Epoch 24/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6548 - acc: 0.6105 - val_loss: 0.6714 - val_acc: 0.5829
# Epoch 25/30
# 46/46 [==============================] - 3s 67ms/step - loss: 0.6586 - acc: 0.6139 - val_loss: 0.6434 - val_acc: 0.6313
# Epoch 26/30
# 46/46 [==============================] - 3s 66ms/step - loss: 0.6583 - acc: 0.6155 - val_loss: 0.6281 - val_acc: 0.6447
# Epoch 27/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6582 - acc: 0.6017 - val_loss: 0.6278 - val_acc: 0.6490
# Epoch 28/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6580 - acc: 0.6172 - val_loss: 0.6247 - val_acc: 0.6509
# Epoch 29/30
# 46/46 [==============================] - 3s 64ms/step - loss: 0.6515 - acc: 0.6242 - val_loss: 0.6249 - val_acc: 0.6587
# Epoch 30/30
# 46/46 [==============================] - 3s 65ms/step - loss: 0.6504 - acc: 0.6145 - val_loss: 0.6209 - val_acc: 0.6535

# %%
plot_train_history(hist_reg)
